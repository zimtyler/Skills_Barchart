# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Skills = ["Excel", "SQL", "Python", "R", "VBA", "Tableau", "Power BI", "Quantitative\nModeling", "Workflow\nAutomation"]
Proficiency = [10, 9, 9, 7, 7, 9, 8, 10, 10]

df = pd.DataFrame(list(zip(Skills, Proficiency)), columns = ["Skills", "Proficiency"])

print(df)
# Out:
#                    Skills  Proficiency
# 0                   Excel           10
# 1                     SQL            9
# 2                  Python            9
# 3                       R            7
# 4                     VBA            7
# 5                 Tableau            9
# 6                Power BI            8
# 7  Quantitative\nModeling           10
# 8    Workflow\nAutomation           10

# %%
#dots per inch of 300
plt.rcParams['figure.dpi'] = 300

sns.set(style='whitegrid')

#adjust size of plot
ax = plt.subplots(figsize=(3, 4))

sns.barplot(data = df,
            x = "Proficiency", 
            y = "Skills",
            palette = 'blend:#323,#479'
            )
#Remove standard x and y axis labels and ticks
plt.xlabel("")
plt.ylabel("")
plt.xticks([], [])
plt.yticks([], [])

# loop over index to label proficiency integer within the bars, setting font to serif to match resume
for i in range(len(Proficiency)):
    plt.text(x=int(Proficiency[i])-.7, 
            y = i,
            s = Proficiency[i],
            color='white',
            fontsize=15,
            family = 'serif',
            horizontalalignment = 'center', 
            verticalalignment = 'center'
            )

#initially tried to loop, but quickly realized that I had to adjust the position of the string individually
#labeling each bar with Skill string
plt.text(x= 1.35, 
         y = 0,
         s = Skills[0],
         color = 'white',
         fontsize=13,
         family = 'serif',
         horizontalalignment = 'center', 
         verticalalignment = 'center'
         )
plt.text(x= 1.05, 
         y = 1,
         s = Skills[1],
         color='white',
         fontsize=13,
         family = 'serif',
         horizontalalignment = 'center', 
         verticalalignment = 'center'
            )
plt.text(x= 1.65, 
         y = 2,
         s = Skills[2],
         color='white',
         fontsize=13,
         family = 'serif',
         horizontalalignment = 'center', 
         verticalalignment = 'center'
            )
plt.text(x= .51, 
         y = 3,
         s = Skills[3],
         color='white',
         fontsize=13,
         family = 'serif',
         horizontalalignment = 'center', 
         verticalalignment = 'center'
            )
plt.text(x= 1.1, 
         y = 4,
         s = Skills[4],
         color='white',
         fontsize=13,
         family = 'serif',
         horizontalalignment = 'center', 
         verticalalignment = 'center'
            )
plt.text(x= 1.85, 
         y = 5,
         s = Skills[5],
         color='white',
         fontsize=13,
         family = 'serif',
         horizontalalignment = 'center', 
         verticalalignment = 'center'
            )
plt.text(x= 2.1, 
         y = 6,
         s = Skills[6],
         color='white',
         fontsize=13,
         family = 'serif',
         horizontalalignment = 'center', 
         verticalalignment = 'center'
            )
plt.text(x= .3, 
         y = 7,
         s = Skills[7],
         color='white',
         fontsize=8.5,
         family = 'serif',
         horizontalalignment = 'left', 
         verticalalignment = 'center'
            )
plt.text(x= .3, 
         y = 8,
         s = Skills[8],
         color='white',
         fontsize=8.5,
         family = 'serif',
         horizontalalignment = 'left', 
         verticalalignment = 'center'
            )
#positioned the "title" at the bottom, really just showing off now
plt.title("*Visualization made with Pandas, Matplotlib, & Seaborn.\n Click image for code!",
          y = -.08,
          horizontalalignment = 'center',
          fontsize = 5,
          family = 'serif'
          )

#Removed the x and y axis for a polished look
sns.despine(left=True,
            bottom = True
            )

# %%
plt.savefig("skills.jpg", bbox_inches="tight",
            pad_inches=0.3, transparent=True)
